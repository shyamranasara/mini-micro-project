# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
datasets = pd.read_csv("heart.csv")
datasets.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
datasets.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# datasets.corr()

# %%
datasets["sex"].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
datasets["cp"].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
datasets["fbs"].value_counts()
# Out:
# fbs
# 0    258
# 1     45
# Name: count, dtype: int64

# %%
datasets["restecg"].value_counts()
# Out:
# restecg
# 1    152
# 0    147
# 2      4
# Name: count, dtype: int64

# %%
datasets["exng"].value_counts()
# Out:
# exng
# 0    204
# 1     99
# Name: count, dtype: int64

# %%
datasets["slp"].value_counts()
# Out:
# slp
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64

# %%
datasets["caa"].value_counts()
# Out:
# caa
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: count, dtype: int64

# %%
datasets["thall"].value_counts()
# Out:
# thall
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64

# %%
datasets["output"].value_counts()
# Out:
# output
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
datasets["restecg"].value_counts()
# Out:
# restecg
# 1    152
# 0    147
# 2      4
# Name: count, dtype: int64

# %%
attributes = datasets.columns

# %%
pd.plotting.scatter_matrix(datasets[attributes],figsize=(20,10))
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='sex', ylabel='age'>,
#         <Axes: xlabel='cp', ylabel='age'>,
#         <Axes: xlabel='trtbps', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='fbs', ylabel='age'>,
#         <Axes: xlabel='restecg', ylabel='age'>,
#         <Axes: xlabel='thalachh', ylabel='age'>,
#         <Axes: xlabel='exng', ylabel='age'>,
#         <Axes: xlabel='oldpeak', ylabel='age'>,
#         <Axes: xlabel='slp', ylabel='age'>,
#         <Axes: xlabel='caa', ylabel='age'>,
#         <Axes: xlabel='thall', ylabel='age'>,
#         <Axes: xlabel='output', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='sex'>,
#         <Axes: xlabel='sex', ylabel='sex'>,
#         <Axes: xlabel='cp', ylabel='sex'>,
#         <Axes: xlabel='trtbps', ylabel='sex'>,
#         <Axes: xlabel='chol', ylabel='sex'>,
#         <Axes: xlabel='fbs', ylabel='sex'>,
#         <Axes: xlabel='restecg', ylabel='sex'>,
# ...

# %%
attributes
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
attribute = ['age',  'trtbps', 'chol',  'thalachh','oldpeak', 'output']

# %%
pd.plotting.scatter_matrix(datasets[attribute],figsize=(20,10))
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='trtbps', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='thalachh', ylabel='age'>,
#         <Axes: xlabel='oldpeak', ylabel='age'>,
#         <Axes: xlabel='output', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='trtbps'>,
#         <Axes: xlabel='trtbps', ylabel='trtbps'>,
#         <Axes: xlabel='chol', ylabel='trtbps'>,
#         <Axes: xlabel='thalachh', ylabel='trtbps'>,
#         <Axes: xlabel='oldpeak', ylabel='trtbps'>,
#         <Axes: xlabel='output', ylabel='trtbps'>],
#        [<Axes: xlabel='age', ylabel='chol'>,
#         <Axes: xlabel='trtbps', ylabel='chol'>,
#         <Axes: xlabel='chol', ylabel='chol'>,
#         <Axes: xlabel='thalachh', ylabel='chol'>,
#         <Axes: xlabel='oldpeak', ylabel='chol'>,
#         <Axes: xlabel='output', ylabel='chol'>],
#        [<Axes: xlabel='age', ylabel='thalachh'>,
# ...

# %% [markdown]
# Remove Outliner Form Datasets

# %%
datasets.plot(kind = "scatter", x = "age" , y="chol")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
datasets.plot(kind = "scatter", x = "age" , y="trtbps")
# Out:
# <Axes: xlabel='age', ylabel='trtbps'>

# %%
datasets.plot(kind = "scatter", x = "age" , y='thalachh')
# Out:
# <Axes: xlabel='age', ylabel='thalachh'>

# %%
datasets.plot(kind = "scatter", x = "age" , y='output')
# Out:
# <Axes: xlabel='age', ylabel='output'>

# %%
datasets.plot(kind = "scatter", x = "chol" , y='thalachh')
# Out:
# <Axes: xlabel='chol', ylabel='thalachh'>

# %%
df= datasets[(datasets["thalachh"]<80)]

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 272   67    1   0     120   237    0        1        71     0      1.0    1
#
#      caa  thall  output
# 272    0      2       0

# %%
datasets = datasets.drop(df.index)

# %%
df1 = datasets[(datasets["chol"]>500)]

# %%
datasets = datasets.drop(df1.index)

# %%
df1
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 85   67    0   2     115   564    0        0       160     0      1.6    1
#
#     caa  thall  output
# 85    0      3       1

# %%
class_3 ,class_2=  datasets["output"].value_counts()

class_3 

class_2

c1 = datasets[datasets["output"]==1]

c2 = datasets[datasets["output"]==0]

df_1 = c1.sample(class_3 ,replace=True)

df_2_over = c2.sample(class_3 , replace=True)

oversample_df = pd.concat([df_1 , df_2_over], axis=0)

# %%
oversample_df["output"].value_counts()
# Out:
# output
# 1    164
# 0    164
# Name: count, dtype: int64

# %%
df  = datasets.copy()

# %%
pd.plotting.scatter_matrix(df[attribute],figsize=(20,10))
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='trtbps', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='thalachh', ylabel='age'>,
#         <Axes: xlabel='oldpeak', ylabel='age'>,
#         <Axes: xlabel='output', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='trtbps'>,
#         <Axes: xlabel='trtbps', ylabel='trtbps'>,
#         <Axes: xlabel='chol', ylabel='trtbps'>,
#         <Axes: xlabel='thalachh', ylabel='trtbps'>,
#         <Axes: xlabel='oldpeak', ylabel='trtbps'>,
#         <Axes: xlabel='output', ylabel='trtbps'>],
#        [<Axes: xlabel='age', ylabel='chol'>,
#         <Axes: xlabel='trtbps', ylabel='chol'>,
#         <Axes: xlabel='chol', ylabel='chol'>,
#         <Axes: xlabel='thalachh', ylabel='chol'>,
#         <Axes: xlabel='oldpeak', ylabel='chol'>,
#         <Axes: xlabel='output', ylabel='chol'>],
#        [<Axes: xlabel='age', ylabel='thalachh'>,
# ...

# %%
df.plot(kind = "scatter", x = "oldpeak" , y='thalachh')
# Out:
# <Axes: xlabel='oldpeak', ylabel='thalachh'>

# %%
df1 = df[(df["chol"]>380)]

# %%
df = df.drop(df1.index)

# %%
df1 = df[(df["oldpeak"]>5)]

# %%
df = df.drop(df1.index)

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# Data Analysis

# %%
import seaborn as sns

# %%
df["age"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='age'>

# %%
df["sex"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='sex'>

# %%
df["cp"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='cp'>

# %%
df["trtbps"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='trtbps'>

# %%
df["fbs"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='fbs'>

# %%
df["restecg"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='restecg'>

# %%
df1 = df[(df["restecg"]==2)]

# %%
df1
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 144   76    0   2     140   197    0        2       116     0      1.1    1
# 266   55    0   0     180   327    0        2       117     1      3.4    1
# 289   55    0   0     128   205    0        2       130     1      2.0    1
# 291   58    1   0     114   318    0        2       140     0      4.4    0
#
#      caa  thall  output
# 144    0      2       1
# 266    0      2       0
# 289    1      3       0
# 291    3      1       0

# %%
df["exng"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='exng'>

# %%
df["slp"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='slp'>

# %%
df["caa"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='caa'>

# %%
df["thall"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='thall'>

# %%
df1 = df[(df["thall"] == 0)]

# %%
df1
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 48    53    0   2     128   216    0        0       115     0      0.0    2
# 281   52    1   0     128   204    1        1       156     1      1.0    1
#
#      caa  thall  output
# 48     0      0       1
# 281    0      0       0

# %%
df1 = df[(df["caa"]==4)]

# %%
df1
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 92    52    1   2     138   223    0        1       169     0      0.0    2
# 158   58    1   1     125   220    0        1       144     0      0.4    1
# 163   38    1   2     138   175    0        1       173     0      0.0    2
# 164   38    1   2     138   175    0        1       173     0      0.0    2
# 251   43    1   0     132   247    1        0       143     1      0.1    1
#
#      caa  thall  output
# 92     4      2       1
# 158    4      3       1
# 163    4      2       1
# 164    4      2       1
# 251    4      3       0

# %%
sns.kdeplot(df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.displot(df["age"])

# %%
sns.kdeplot(df.trtbps, fill = True )
# Out:
# <Axes: xlabel='trtbps', ylabel='Density'>

# %%
sns.kdeplot(df.thalachh , fill= True)
# Out:
# <Axes: xlabel='thalachh', ylabel='Density'>

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  295.000000  295.000000  295.000000  295.000000  295.000000  295.000000
# mean    54.155932    0.694915    0.979661  131.467797  243.420339    0.149153
# std      9.085914    0.461226    1.033253   17.604252   45.060574    0.356844
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     60.000000    1.000000    2.000000  140.000000  273.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  360.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  295.000000  295.000000  295.000000  295.000000  295.000000  295.000000
# mean     0.535593  149.959322    0.328814    0.992203    1.413559    0.718644
# ...

# %% [markdown]
# Spliting and Treaning MOdels

# %%
from sklearn.model_selection import train_test_split , cross_val_score

# %%
features = df.drop(["output"], axis = 1)

# %%
features
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall
# 0      0      1
# 1      0      2
# ...

# %%
labels = df["output"]

# %%
labels
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 295, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(features , labels , test_size=0.3 , random_state=103)

# %%
x_train.head()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 35    46    0   2     142   177    0        0       160     1      1.4    0
# 87    46    1   1     101   197    1        1       156     0      0.0    2
# 139   64    1   0     128   263    0        1       105     1      0.2    1
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 231   57    1   0     165   289    1        0       124     0      1.0    1
#
#      caa  thall
# 35     0      2
# 87     0      3
# 139    1      3
# 2      0      2
# 231    3      3

# %%
len(x_test)
# Out:
# 89

# %%
len(y_train)
# Out:
# 206

# %%
len(y_test)
# Out:
# 89

# %%
from sklearn.ensemble import RandomForestClassifier , AdaBoostClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import f1_score

# %%
classifiers = [['Random Forest Classifier', RandomForestClassifier()],
              ['Ada Boost Classifier' , AdaBoostClassifier()],
              ['Gaussian Process Classifier' , GaussianProcessClassifier()],
              ['KNeighbors Classifier' , KNeighborsClassifier()],
              ['MLP Classifier', MLPClassifier()],
              ['Decision Tree Classifier' , DecisionTreeClassifier()],
              ['SDG Classifier', SGDClassifier()],
              ['Gradient Boosting Classifier', GradientBoostingClassifier(learning_rate=0.1, n_estimators=500)],
              ['Hist Gradient Bossting Classifier', HistGradientBoostingClassifier()]]

# %%
Accuracy = []
for clas in classifiers:
    name = clas[0]
    model = clas[1]
    model.fit(x_train , y_train)
    y_pred = model.predict(x_test)

    # cross_val_score = cross_val_score(model , x_train , y_train, cv=1)
    Accuracy.append(pd.Series({"Model :-": name,"F1 Score :-" : f1_score(y_test , y_pred ) }))

# %%
Accuracy
# Out:
# [Model :-       Random Forest Classifier
#  F1 Score :-                         0.8
#  dtype: object,
#  Model :-       Ada Boost Classifier
#  F1 Score :-                0.755556
#  dtype: object,
#  Model :-       Gaussian Process Classifier
#  F1 Score :-                       0.607843
#  dtype: object,
#  Model :-       KNeighbors Classifier
#  F1 Score :-                 0.666667
#  dtype: object,
#  Model :-       MLP Classifier
#  F1 Score :-          0.567164
#  dtype: object,
#  Model :-       Decision Tree Classifier
#  F1 Score :-                    0.721649
#  dtype: object,
#  Model :-       SDG Classifier
#  F1 Score :-              0.68
#  dtype: object,
#  Model :-       Gradient Boosting Classifier
#  F1 Score :-                        0.826087
#  dtype: object,
#  Model :-       Hist Gradient Bossting Classifier
#  F1 Score :-                                  0.8
#  dtype: object]

# %%
from sklearn.multiclass import OneVsOneClassifier

# %%
model = GradientBoostingClassifier(learning_rate=0.1, n_estimators=500)

# %%
model.fit(x_train , y_train)
# Out:
# GradientBoostingClassifier(n_estimators=500)

# %%
y_pred = model.predict(x_test)

# %%
f1_score(y_test , y_pred )
# Out:
# 0.8260869565217391
